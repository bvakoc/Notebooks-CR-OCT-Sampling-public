# %% [markdown]
# ##### &copy; Norman Lippok | nlippok@mgh.harvard.edu
#
# <h1>Optimal system design for CR-OCT</h1>
# <h1>Part 1. | Circular-ranging signals</h1>
#
# This Notebook serves as supplementary material to illustrates elements of a CR-OCT signal. The output of this simulation represents the physical (optical) signal before low-pass filtering and sampling.

# %% [markdown]
# <h3>Exercise</h3>
# <ol>
#     <li>Slowly change the RF frequency (depth) and observe the signal in the baseband and higher harmonics.</li>
#     <li>Turn quadrature detection ('I/Q') off and observe the changing signal and harmonics.</li>
#     <li>Turn background subtraction ('BG') off and observe the signal and harmonics.</li>
#     <li>With background subtraction off, decrease the pulse width and observe pulse artefacts at $2f_o=f_p$.</li>
#     <li>Using linear scale ('Log' off, 'BG' on, 'I/Q' on, pulse width = 10), slowly change the RF frequency and observe the sinc baseband rolloff. Make sure normalization ('Norm') is off to observe the changing signal magnitude. If signal magnitude is too small for viewing, adjust signal magnitude by briefly toggling normalization ('Norm') on/off.</li>
#     <li>Repeat last exercise for a smaller pulse width (e.g. 0.5) and see how the rolloff is affected by pulsation.</li>
# </ol>

# %%
# %run ./proc.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Documents/GitHub/Notebooks-CR-OCT-Sampling-public/Part1/libs.ipynb in <module>
#       1 #Libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 import matplotlib.transforms as mtransforms
#
# ModuleNotFoundError: No module named 'pandas'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Documents/GitHub/Notebooks-CR-OCT-Sampling-public/Part1/proc.ipynb in <module>
# ----> 1 get_ipython().run_line_magic('run', './libs.ipynb')
#       2
#       3 pulsew = 5
#       4
#       5 get_ipython().run_line_magic('run', './ini.ipynb')
#
# ...

# %% [markdown]
# <h3>Description</h3>
#
# <b>Graph</b>
# <ul type="square">
#     <li>The graph shows the CR depth signal.</li>
#     <li>The x-axis represents the normalized RF-frequency with respect to the optical Nyquist frequency.</li>
#     <li>The blue shaded area indicates the circular (depth) range.</li>
# </ul>
#
# <b>Interactive tools</b>
# <ul>
#     <li>'PulseWidth' &nbsp;&nbsp;&nbsp;&nbsp;Changes the pulse width (FWHM). Pulse FWHM is normalized to the (inverse) pulse repetition rate, $1/f_p=t_p$.</li>
#     <li>'$f/f_o$' &nbsp;&nbsp;&nbsp;&nbsp;Changes the RF fringe frequency (signal depth). It is normalized to the optical Nyquist frequency.</li>
#     <li>'I/Q' &nbsp;&nbsp;&nbsp;&nbsp;Turns quadrature signal on and off.</li>
#     <li>'BG' &nbsp;&nbsp;&nbsp;&nbsp;Tuns background subtraction on and off.</li>
#     <li>'Log' &nbsp;&nbsp;&nbsp;&nbsp;Switches between log and linear scale.</li>
#     <li>'Norm' &nbsp;&nbsp;&nbsp;&nbsp;Normalizes the signal amplitude. Saves the last normalization value when disabling.</li>
# </ul>
