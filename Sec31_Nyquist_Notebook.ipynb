# %% [markdown]
# ##### &copy; Norman Lippok | nlippok@mgh.harvard.edu
#
# <h1>Section 3.1. | Acquisition clock phase</h1>
#
# This Notebook serves as supplementary material to Sec. 3.1. and Figs. 6,7. It illustrates the dependency of the signal magnitude on the acquisition clock phase in Nyquist sampling. We show the effect of the clock phase on the fringe signal and the depth signal.

# %% [markdown]
# <h2>Fringe signal</h2>
#
# <b>Exercise</b>
# <ol>
#     <li>Slowly change the RF fringe frequency and observe changes in the CR signal.</li>
#     <li>Pay attention to the stepped fringe (blue line) that converges to a rectangular fringe as the fringe frequency approaches the optical Nyquist frequency.</li>
#     <li>Slowly change the acquisition clock phase and observe changes in the sampled signal (green line).</li>
#     <li>Repeat the previous excerise for a low fringe frequency and high fringe frequency (e.g., $f = f_o$). Observe how the signal magnitude is more dependent on the acquisition clock phase for high RF frequencies. Observe how the sampled signal (green line) can be lost at the optical Nyquist frequency in the case of a misaligned clock phase.</li>
# </ol>

# %%
# %run ./Sec31_1.ipynb
# Out:
# HBox(children=(FloatSlider(value=1.0, description='$f/f_o$', layout=Layout(width='400px'), max=1.0, step=0.05)…
# Output()

# %% [markdown]
# <b>Description</b>
# <ul type="square">
#     <li>The graph computes a CR fringe signal, showing the pysical signal (befor detection, blue line), the detected and analog low-pass filtered signal (yellow line) and the Nyquist sampled signal (green line).</li>
#     <li>'$f/f_o$' &nbsp;&nbsp;&nbsp;&nbsp;Changes the RF fringe frequency (signal depth). It is normalized to the optical Nyquist frequency.</li>
#     <li>'Clock Phase' &nbsp;&nbsp;&nbsp;&nbsp;Changes the acquistion clock phase (in radians).</li>
# </ul>

# %% [markdown]
# <h2>Depth signal</h2>
#
# <b>Exercise</b>
# <ol>
#     <li>With I/Q 'on' and Log 'off' (linear scale), observe the signal loss when approaching optical Nyquist frequency due to
#         acquisition clock phase misalignment.</li>
#     <li>Optimize the acquisition clock phase by maximizing the PSF magnitude at a depth near the optical Nyquist frequency.</li>
# </ol>

# %%
# %run ./Sec31_2.ipynb
# Out:
# HBox(children=(FloatSlider(value=0.2, description='$f/f_o$', layout=Layout(margin='1px 1px', width='400px'), m…
# HBox(children=(Output(), ToggleButton(value=True, description='Log', layout=Layout(margin='13px 0px'))), layou…

# %% [markdown]
# <b>Description</b>
# <ul type="square">
#     <li>Here we plot the CR signal in the RF (depth) domain after Fourier transformation</li>
#     <li>The x-axis represents the normalized RF-frequency with respect to the optical Nyquist frequency</li>
#     <li>'I/Q' &nbsp;&nbsp;&nbsp;&nbsp;Turns quadature detection on and off.</li>
#     <li>'Log' &nbsp;&nbsp;&nbsp;&nbsp;Switches between linear and logarithmic scale.</li>
#     <li>'$f/f_o$'  &nbsp;&nbsp;&nbsp;&nbsp;Changes the signal depth (fringe frequency). It is normalized to the optical Nyquist frequency.</li>
#     <li>'Clock Phase' &nbsp;&nbsp;&nbsp;&nbsp;Changes the acquistion clock phase (in radians).</li>
# </ul>
