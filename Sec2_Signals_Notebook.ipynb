# %% [markdown]
# <b> <h1>Section 3.2. | Circular-ranging signal</h1> </b>
#
# This Notebook serves as supplementary material to Sec. 3.2. It illustrates components of CR-OCT signals.

# %% [markdown]
# <b> <h3>Exercise</h3> </b>
# <ul type="square">
#     <li>Slowly change the RF frequency (depth) and observe the signal in the baseband and higher harmonics.</li>
#     <li>With I/Q off, slowly change the RF frequency (depth) and observe the signal in the baseband and higher harmonics.</li>
#     <li>With no background subtraction, slowly change the RF frequency (depth) and observe the signal in the baseband and higher harmonics.</li>
#     <li>With no background subtraction, change the pulse width and observe pulse artefacts at $2f_o=f_p$.</li>
#     <li>Using linear scale, slowly change the RF frequency and observe the sinc baseband roll-off. Start at zero RF frequency and press the 'Norm' button twice (i.e. normalize) before moving the PSF across the baseband. </li>
# </ul>

# %%
# %run ./Sec2.ipynb

# %% [markdown]
# <h3>Description</h3>
#
# <b>Graph</b>
# <ul type="square">
#     <li>The graph shows the CR depth signal.</li>
#     <li>The x-axis represents the normalized RF-frequency with respect to the optical Nyquist frequency.</li>
#     <li>The blue shaded area indicates the circular (depth) range (4th checkbox).</li>
# </ul>
#
# <b>Interactive tools</b>
# <ul>
#     <li>The 'PulseWidth' box changes the pulse width. It's FWHM is normalized to the (inverse) pulse repetition rate.</li>
#     <li>The RF fringe frequency (signal depth) can be adjusted with the '$f/f_o$' slider. It is normalized to the optical Nyquist frequency.</li>
#     <li>The 'I/Q' button turns the quadrature signal on and off.</li>
#     <li>The 'BG' button performs background subtraction.</li>
#     <li>The 'Log' button switches between log and linear scale.</li>
#     <li>The 'Norm' button normalizes the signal amplitude. Saves the last normalization value when disabling.</li>
# </ul>
