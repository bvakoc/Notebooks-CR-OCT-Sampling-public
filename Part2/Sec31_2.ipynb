# %%
# %run ./libs.ipynb
# %run ./initialize.ipynb
# %run ./signals_sec31.ipynb

Noversampl = 1

def getSig(IQ_button, LOG_button, ph_slide, f_slide):
    
    IQ = IQ_button
    LOG = LOG_button
    ph0 = ph_slide
    f = f_slide
    depth0 = f*LB/2*1e6
    
    sf, sfilt, ss, Ss, dsampled, snr = signals_sec31(Noversampl, depth0, oof, ofcont, FILT, Order, FiltType, FILTFACT, AutoPhase, ph0, IQ, noise, SNR)
    
    rf_vec = np.linspace(-1,1,len(dsampled))
    
    if IQ:
        Ss = Ss/3.11e-7
    else:
        Ss = Ss/(3.11e-7/4)
    
    if LOG:
        Ss = 10*np.log10(Ss)
        
    fig = plt.figure(figsize = (13,4))
    ax = fig.add_subplot(111)
    
    line1 = ax.plot(rf_vec, Ss,'k', linewidth='2')
    plt.ylabel('Signal, a.u.', fontsize = 15)
    plt.xlabel('$f/f_o$', fontsize = 15)
    #plt.xlim([-LB/2*1e3, LB/2*1e3])
    plt.xlim([-1, 1])
    plt.grid(color='k', linestyle='-', linewidth=.1)
    
    if LOG:
        plt.ylim([-55, 2])
    else:
        plt.ylim([0, 1.05])    
         
       
# IQ
IQ_button = widgets.ToggleButton(value = True, description = 'I/Q', layout=Layout(margin='1px 30px')) 

# log
LOG_button = widgets.ToggleButton(value = True, description = 'Log', layout=Layout(margin='13px 0px')) 

# clock phase
ph_slide = widgets.FloatSlider(value = 0,
                               description = 'Clock Phase',
                               min = 0,
                               max = 2*np.pi,
                               step = 2*np.pi/10,
                               continuous_update = True,
                               layout=Layout(width='400px', margin='1px 30px'))

# depth
f_slide = widgets.FloatSlider(value = .2,
                              description = '$f/f_o$',
                              min = -2,
                              max = 2,
                              step = .05,
                              continuous_update = True,
                              layout=Layout(width='400px', margin='1px 1px'))

#widgets.interact(getSig, IQ = IQ_button, LOG = LOG_button, ph0 = ph_slide, f = f_slide)


ui1 = widgets.HBox([f_slide, IQ_button, ph_slide], layout=widgets.Layout(align_items='flex-start'))

#ui1 = widgets.VBox([IQ_button, LOG_button])
#ui2 = widgets.VBox([f_slide, ph_slide])
#ui3 = widgets.HBox([ui1, ui2])

out = widgets.interactive_output(getSig, {'IQ_button': IQ_button, 'LOG_button': LOG_button, 'ph_slide': ph_slide, 'f_slide': f_slide})

ui2 = widgets.HBox([out, LOG_button], layout=widgets.Layout(align_items='flex-start'))

display(Image(filename='setup_sec31_2.png', width="860"))

display(ui1,ui2)
